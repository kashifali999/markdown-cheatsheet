# %%
say_hello()
# Out:
# Hello from Kashif Ali

# %%
def say_hello():
    """Just say hello"""
    print("Hello from Kashif Ali")

# %% [markdown]
# Functio without parameters

# %%
introduction("Kashif", 40)
# Out:
# Hello my name is Kashif and I am 40 years old

# %%
def introduction(name, age):
    """Introduction"""
    print(f"Hello my name is {name} and I am {age} years old")

# %%
add(2.423, 3.523, 0)
# Out:
# 5.95

# %%
def add(a, b, c):
    """Addition"""
    return round(a+b, 2)

# %%
# ?mean
# Out:
# Signature: mean(numbers)
# Docstring: Mean of numbers
# File:      c:\users\kashif ali\appdata\local\temp\ipykernel_13040\1271476102.py
# Type:      function

# %%
price = [10,20,30, 37, 99, 10387]
mean(price)
# Out:
# 1763.833

# %%
def mean(numbers):
    """Mean of numbers"""
    return round(sum(numbers) / len(numbers), 3)

# %%
greet("Kashif")
# Out:
# Hello Kashif

# %%
def greet(name):
    """Greeting"""
    print(f"Hello {name}")

# %%
min((20,30,80))
# Out:
# 20

# %%
sum((20,30,80))
# Out:
# 130

# %%
input("Enter name")
# Out:
# 'kashif'

# %%
len("Kashif")
# Out:
# 6

# %%
print("Kashif")
# Out:
# Kashif
