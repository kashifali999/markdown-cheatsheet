# %% [markdown]
# Function with default parameter

# %%
def intro(name="Kashif"):
    """Default parameter"""
    print("I am " + name + " and my age is")

# %%
intro()
# Out:
# I am Kashif and my age is

# %% [markdown]
# lambda function - anonymous function

# %%
lambda arguments: expressions
# Out:
# <function __main__.<lambda>(arguments)>

# %%
add_lambda = lambda x, y: x + y
result = add_lambda(2, 3)
print(result)
# Out:
# 5

# %%
sqr = lambda x, y: x**y

# %%
ans = sqr(5, 2)
print(ans)
# Out:
# 25

# %%
numbers = [100, 200, 300, 400, 500]

squared = map(lambda x: x**2, numbers)

print(list(squared))
# Out:
# [10000, 40000, 90000, 160000, 250000]

# %% [markdown]
# User input

# %%
age = input("How old are you ?")
age = int(age)

# %%
my_age = int(input("I am year old"))

# %%
cell_number = int(input("Enter cell number"))
print(f"my cell number is {cell_number} warid network")
# Out:
# my cell number is 320 warid network
